# %%
import matplotlib.pyplot as plt
import pickle
import os

# %%
path_to_experiment = "logs/unet_attention_0"

with open(os.path.join(path_to_experiment,'train_losses.pkl'), 'rb') as f:
            train_losses = pickle.load(f)
with open(os.path.join(path_to_experiment,'val_losses.pkl'), 'rb') as f:
            val_losses = pickle.load(f)
with open(os.path.join(path_to_experiment,'lr.pkl'), 'rb') as f:
            lr_list = pickle.load(f)

# %%
fig = plt.figure(figsize=(10,3))
plt.subplot(121)
plt.plot(train_losses, label='train')
plt.plot(val_losses, label='val')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.title("Train and validation errors")
plt.legend()

plt.subplot(122)
plt.plot(lr_list, label='learning rate')
plt.xlabel('Epochs')
plt.ylabel('lr')
plt.legend()

plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9)
plt.plot()
# Out:
# []

# %%
path_to_final_output = "data/test_data"

with open(os.path.join(path_to_final_output,'results.pickle'), 'rb') as f:
            outputs = pickle.load(f)

# %%
outputs.keys()
# Out:
# dict_keys(['outputs', 'paths'])

# %%
outputs["outputs"].shape
# Out:
# (1, 256, 256, 1)

# %%
plt.imshow(outputs["outputs"][0,:,:,0])
